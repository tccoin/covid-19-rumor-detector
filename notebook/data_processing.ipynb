# %%
import pandas as pd
from pandas import Series, DataFrame
import re
import numpy as np

# %%
# label the google rumors
dxy_rumors=pd.read_csv('../data/DXY_rumors.csv')
google_rumors=pd.read_csv('../data/Google_rumors.csv')
label_dict= {}
for i in range(len(dxy_rumors)):
    label_dict[dxy_rumors.title[i][0:-1]] = dxy_rumors.rumorType[i]
label = np.zeros(len(google_rumors),dtype=int)
for i in range(len(google_rumors)):
     label[i] = label_dict[google_rumors.keyword[i]]
google_rumors['label'] = label
google_rumors.to_csv('../data/Google_rumors.csv',index=False)

# %%
# ?pd.save_csv
# Out:
# Object `pd.save_csv` not found.

# %%
google_rumors

# %%
news= pd.read_csv('./data/DXY_news.csv')
news['label'] = 3
news['data'] = news['title']+news['summary']
news= news.drop(["_id","id","title","pubDate","summary","infoSource","sourceUrl","provinceId","crawlTime","entryWay","infoType","dataInfoState","dataInfoOperator","dataInfoTime","provinceName","createTime","modifyTime","adoptType","body"], axis=1)
#news
google_rumor= pd.read_csv('./data/Google_rumors.csv')
google_rumor['m_data'] = google_rumor['title']+google_rumor['summary']
google_rumor= google_rumor.drop(["Unnamed: 0","keyword","summary","title","link","visible_link","date","rank"], axis=1)
google_rumor.columns = ['label', 'data']
#google_rumor
final=pd.concat([google_rumor,news],axis=0)
final
final.to_csv('./data/much_data.csv')

# %%
news= pd.read_csv('./data/DXY_news.csv')
news['label'] = 3
news['data'] = news['title']+news['summary']
news= news.drop(["_id","id","title","pubDate","summary","infoSource","sourceUrl","provinceId","crawlTime","entryWay","infoType","dataInfoState","dataInfoOperator","dataInfoTime","provinceName","createTime","modifyTime","adoptType","body"], axis=1)
#news
google_rumor= pd.read_csv('./data/Google_rumors.csv')
google_rumor['m_data'] = google_rumor['title']+google_rumor['summary']
google_rumor= google_rumor.drop(["Unnamed: 0","keyword","summary","title","link","visible_link","date","rank"], axis=1)
google_rumor.columns = ['label', 'data']
#google_rumor
final=pd.concat([google_rumor,news],axis=0)
final
final.to_csv('./data/much_data.csv')
# Out:
#               keyword                                title  \
# 0     疫情期间大强度锻炼可提高抵抗力              疫情期间是否可以通过大强度的锻炼来提高抵抗力？
# 1     疫情期间大强度锻炼可提高抵抗力     都说体育锻炼能增强体质，提高免疫力，疫情期间是否可以通过 ...
# 2     疫情期间大强度锻炼可提高抵抗力                疫情期间可以通过大强度的锻炼来提高抵抗力？
# 3     疫情期间大强度锻炼可提高抵抗力       疫情期间可以通过大强度锻炼提高抵抗力? - 青海省科学技术厅
# 4     疫情期间大强度锻炼可提高抵抗力    【够科普】疫情期间是否可以通过大强度锻炼来提高抵抗力？ _ ...
# ...               ...                                  ...
# 5116            深圳要封城                         深圳要“封城”？ 谣言！
# 5117            深圳要封城                 深圳要“封城”？谣言！-股票频道-金融界
# 5118            深圳要封城  成都、深圳一線大城相繼封城「要不要復工」讓中國網民吵翻| 台灣 ...
# 5119            深圳要封城              深圳要「封城」？謠言！-財經新聞-新浪新聞中心
# 5120            深圳要封城     【武漢肺炎】「封城」消息廣傳北京、廣州、深圳宣布不會封城 ...
#
#                                                 summary  \
# 0     2020年3月3日 - 国家体育总局体育科学研究所研究员 徐建方. 首先要明确，居家健身不适...
# 1     2020年3月1日 - 首先要明确居家健身不宜进行长时间大强度锻炼。在居家防疫期间，为确保运...
# 2     流传内容：新型冠状病毒肺炎主要依靠自身免疫力，所以在家做高强度运动可以提高免疫力，抵御病毒感...
# 3     2020年4月15日 - 谣言：居家防疫特殊时期，提高抵抗力的有效方法是进行大强度的体育锻炼...
# 4     2020年3月2日 - 央视网消息：都说体育锻炼能够增强体质、提高免疫力。疫情期间是否可以通...
# ...                                                 ...
# 5116  编辑：第一现场. 版权声明：节目版权由深圳广播电视电影集团所有权，未经许可，严禁转载. 4....
# 5117  2020年1月26日 - 证券时报e公司讯，记者1月26日下午从深圳市新型冠状病毒感染的肺炎...
# 5118  2020年2月8日 - 中國新型冠狀病毒肺炎疫情逐漸失控，繼昨（08）日廣州市宣佈「封鎖式管...
# 5119  深圳要「封城」？謠言！ 北京新浪網01-26 18:37. 字級變小. 字級加大. 1月26...
# 5120  2020年1月27日 - 有網傳消息指，深圳27日開始要封城，「龍大，南光，107都要封」。...
#
#                                                    link  \
# 0     http://www.nhc.gov.cn/xcs/kpzs/202003/6337c139...
# 1     http://www.nhc.gov.cn/xcs/nwwd/202003/05ce77a5...
# 2     http://static.scms.sztv.com.cn/ysz/9a071557/tt...
# 3        http://kjt.qinghai.gov.cn/content/show/id/6529
# 4     http://www.ce.cn/xwzx/gnsz/gdxw/202003/02/t202...
# ...                                                 ...
# 5116  http://static.scms.sztv.com.cn/ysz/9a071557/jc...
# 5117  http://stock.jrj.com.cn/2020/01/26183828736604...
# 5118      https://www.taiwannews.com.tw/ch/news/3873422
# 5119  https://news.sina.com.tw/article/20200126/3408...
# 5120  https://www.hk01.com/%E5%A4%A7%E5%9C%8B%E5%B0%...
#
#                                visible_link        date  rank  label
# 0               www.nhc.gov.cn › xcs › kpzs   2020年3月3日     1      0
# 1               www.nhc.gov.cn › xcs › nwwd   2020年3月1日     2      0
# 2             static.scms.sztv.com.cn › ysz         NaN     3      0
# 3       kjt.qinghai.gov.cn › content › show  2020年4月15日     4      0
# 4                 www.ce.cn › 新闻 › 国内时政更多新闻   2020年3月2日     5      0
# ...                                     ...         ...   ...    ...
# 5116  static.scms.sztv.com.cn › ysz › jcdsp         NaN    16      0
# 5117         stock.jrj.com.cn › 股票频道 › 上市公司  2020年1月26日    17      0
# 5118           www.taiwannews.com.tw › news   2020年2月8日    18      0
# 5119             news.sina.com.tw › article         NaN    19      0
# 5120         www.hk01.com › 大國小事 › 武漢肺炎-...  2020年1月27日    20      0
#
# [5121 rows x 8 columns]

# %%
news= pd.read_csv('./data/DXY_news.csv')
news['label'] = 3
news['data'] = news['title']+news['summary']
news= news.drop(["_id","id","title","pubDate","summary","infoSource","sourceUrl","provinceId","crawlTime","entryWay","infoType","dataInfoState","dataInfoOperator","dataInfoTime","provinceName","createTime","modifyTime","adoptType","body"], axis=1)
#news
google_rumor= pd.read_csv('./data/Google_rumors.csv')
google_rumor['m_data'] = google_rumor['title']+google_rumor['summary']
google_rumor= google_rumor.drop(["Unnamed: 0","keyword","summary","title","link","visible_link","date","rank"], axis=1)
google_rumor.columns = ['label', 'data']
#google_rumor
final=pd.concat([google_rumor,news],axis=0)
final
final.to_csv('./data/much_data.csv')

# %%
import json
results = []
for page_number in range(1,6): 
    json_str = open('../data/piyao/{}.json'.format(page_number),'r').read()
    json_page = json.loads(json_str)
    json_list = json_page['data']['list']
    for item in json_list:
        results.append([*item.values()])
columns = [*page_json['data']['list'][0].keys()]
columns = [x.lower() for x in columns]
results = pd.DataFrame(results,columns=columns)
results = results.drop([
 'docid',
#  'title',
 'nodeid',
#  'pubtime',
#  'linkurl',
 'abstract',
#  'keyword',
#  'editor',
#  'author',
 'islink',
#  'sourcename',
 'piclinks',
 'ismoreimg',
 'imgarray',
 'subtitle',
 'attr',
 'm4v',
 'tarray',
 'uarray',
 'allpics',
 'introtitle',
 'ext1',
 'ext2',
 'ext3',
 'ext4',
 'ext5',
 'ext6',
 'ext7',
 'ext8',
 'ext9',
 'ext10'],axis=1)
results.keyword[results.keyword == '快递'] = '谣言'
results.keyword[results.keyword == 'None'] = '谣言'
results = results[results.keyword != '辟谣']
results.keyword[results.keyword == '谣言'] = 0
results.keyword[results.keyword == '事实'] = 1
results.keyword[results.keyword == '误区'] = 2
results = results.drop(results.index[results.keyword.isnull()])
results.to_csv('../data/piyao.csv')

# %%
results.keyword.unique()
# Out:
# array(['谣言', '误区', '事实'], dtype=object)

# %%
results
# Out:
#                           title              pubtime  \
# 0                  广西有人3次检测呈阳性？  2020-06-28 10:49:26
# 1                   蚊蝇可以传播新冠病毒？  2020-06-28 10:49:51
# 2      南昌民德路锦江之星酒店发现有俄罗斯人患新冠肺炎？  2020-06-26 11:05:25
# 4             市民路过中高风险地区健康码会变色？  2020-06-24 15:44:27
# 5                上海30天内禁止跨省旅游团？  2020-06-24 16:28:01
# ..                          ...                  ...
# 995             中国向菲律宾捐赠20万只口罩？  2020-02-11 23:21:37
# 996   疫情致广西防城港市，玉林市博白县、陆川县米粮断供？  2020-02-12 08:42:01
# 997                 黑龙江省疫情数据翻倍？  2020-02-11 22:55:06
# 998  长沙封城、株洲封外地户口进不了城，一律凭身份证进城？  2020-02-12 08:36:35
# 999           北京西站防控失败致大批外地人涌入？  2020-02-10 14:19:36
#
#                                                linkurl keyword editor author  \
# 0    http://www.piyao.org.cn/2020-06/28/c_121067970...      谣言    张智萍   None
# 1    http://www.piyao.org.cn/2020-06/28/c_121067958...      谣言    张智萍   None
# 2    http://www.piyao.org.cn/2020-06/26/c_121067743...      谣言    张智萍   None
# 4    http://www.piyao.org.cn/2020-06/24/c_121067535...      谣言     冯栋     张璐
# 5    http://www.piyao.org.cn/2020-06/24/c_121067536...      谣言     冯栋     白璐
# ..                                                 ...     ...    ...    ...
# 995  http://www.piyao.org.cn/2020-02/11/c_121046411...      谣言    张智萍   None
# 996  http://www.piyao.org.cn/2020-02/12/c_121047075...      谣言    张智萍   None
# 997  http://www.piyao.org.cn/2020-02/11/c_121046876...      谣言    张智萍   None
# 998  http://www.piyao.org.cn/2020-02/12/c_121047076...      谣言    张智萍   None
# 999  http://www.piyao.org.cn/2020-02/10/c_121046792...      谣言    张智萍   None
#
#          sourcename
# 0              昭平公安
# 1             中国新闻网
# 2               央广网
# 4               新京报
# 5            上海网络辟谣
# ..              ...
# 995     中国驻菲律宾大使馆官网
# 996       防城港市市场监管局
# 997             东北网
# 998  湖南省长沙市交警支队官方微博
# 999        北京西站官方微博
#
# [948 rows x 7 columns]

# %%
results[results.keyword == None]
# Out:
# Empty DataFrame
# Columns: [title, pubtime, linkurl, keyword, editor, author, sourcename]
# Index: []
